# %%
from numpy.fft import fft, fftfreq
import wave
from scipy import fftpack
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
import numpy as np
framerate, data=read("Downloads/1.wav")
#mp.figure(1)
#mp.plot(data)
print(framerate, len(data))
raw_fft=fft(data)
#mp.figure(2)
plt.plot(raw_fft)
# Out:
# 44100 80640
# C:\Users\dell\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# [<matplotlib.lines.Line2D at 0x2297a2724a8>,
#  <matplotlib.lines.Line2D at 0x2297a2725f8>]

# %%
import numpy as np
plt.plot(list(np.fft.fft(data)))
# Out:
# [<matplotlib.lines.Line2D at 0x2297c776518>,
#  <matplotlib.lines.Line2D at 0x2297c7766a0>]

# %%
from scipy.io.wavfile import read
rate, data=read("Downloads/1.wav")
import matplotlib.pyplot as plt
plt.plot(data)
plt.show()
from scipy.fftpack import fft, ifft
y = fft(data)
plt.plot(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#first read audio
from scipy.io.wavfile import read
from matplotlib.pyplot import plot
framerate, data=read("Downloads/1.wav")
plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x219cfadf548>,
#  <matplotlib.lines.Line2D at 0x219cfae8588>]

# %%
#second we will do fft
import matplotlib.pyplot as plt
from numpy.fft import fft
plt.plot(data)
plt.plot(fft(data))
# Out:
# [<matplotlib.lines.Line2D at 0x219d4a2d6c8>,
#  <matplotlib.lines.Line2D at 0x219d4a54ec8>]
